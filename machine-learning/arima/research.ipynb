# %% [markdown]
# ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
# <hr>

# %%
# For more information see [https://www.quantconnect.com/docs/research/overview]
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels as sm
from statsmodels.tsa.stattools import adfuller, kpss, acf, pacf, grangercausalitytests
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.graphics import api as smg

# %%
    #Dickey-Fuller test stolen from https://www.hackdeploy.com/augmented-dickey-fuller-test-in-python/
    def ADF_Stationarity_Test(timeseries, significance_level=0.05, printResults = True):
        is_stationary = None
        
        adf_test = adfuller(timeseries, autolag='AIC')
        pValue = adf_test[1]
        
        if (pValue<significance_level):
            is_stationary = True
        else:
            is_stationary = False
        
        if printResults:
            dfResults = pd.Series(adf_test[0:4], index=['ADF Test Statistic','P-Value','# Lags Used','# Observations Used'])
            #Add Critical Values
            for key,value in adf_test[4].items():
                dfResults['Critical Value (%s)'%key] = value
            print('Augmented Dickey-Fuller Test Results:')
            print(dfResults)
            print('Is it stationary? '+str(is_stationary))
        else:
            return is_stationary

# %%
hist = pd.read_csv('bitcoin_historical_data.csv')
hist['Open'] = (pd.to_numeric(hist['Open'] ,  errors='coerce', ))
print(hist.head())
print('Running Augmented Dickey-Fuller Test for Crude Oil...\n')
#ADF_Stationarity_Test(hist['Open'].values)
# Out:
#            Date     Price  Open      High       Low     Vol. Change %
# 0  Jan 23, 2021  32,847.9   NaN  33,441.4  32,088.2  150.68K   -0.46%
# 1  Jan 22, 2021  33,000.5   NaN  33,821.2  28,871.2  243.09K    7.00%
# 2  Jan 21, 2021  30,842.1   NaN  35,591.1  30,101.8  253.27K  -13.06%
# 3  Jan 20, 2021  35,476.3   NaN  36,384.4  33,444.5  153.61K   -1.46%
# 4  Jan 19, 2021  36,002.9   NaN  37,821.0  36,001.4   79.11K   -1.67%
# Running Augmented Dickey-Fuller Test for Crude Oil...

# %%
# Note: Will import training data later.
"""
# We need to split the series into training and testing data
n_obs=80
X_train_oil, X_test_oil = oil_data['close'][0:-n_obs], oil_data['close'][-n_obs:]
print("Oil:")
print(X_train_oil.shape, X_test_oil.shape)

print()

# We need to split the series into training and testing data
n_obs=80
X_train_forex, X_test_forex = forex_data['close'][0:-n_obs], oil_data['close'][-n_obs:]
print("Cad")
print(X_train_forex.shape, X_test_forex.shape)

# Difference the training data to make it stationary

train_oil = X_train_oil.dropna().values.tolist()
train_forex = X_train_forex.dropna().values.tolist()

stationary_oil_data = pd.DataFrame(difference(train_oil))
stationary_forex_data = pd.DataFrame(difference(train_forex))

stationary_oil_data.plot(title='Stationary Crude Oil')
stationary_forex_data.plot(title='Stationary Forex')
"""
print('Wow')
# Out:
# Wow

# %%
# create a differenced series
def difference(series, interval=1):
    diff = []
    for i in range(interval, len(series)):
        value = series[i] - series[i - interval]
        diff.append(value)
    return diff

# %%
print('Making data stationary...\n')
stationary_oil_data = pd.DataFrame(difference(oil_data['close']))
stationary_forex_data = pd.DataFrame(difference(forex_data['close']))

stationary_oil_data.plot(title='Stationary Crude Oil')
stationary_forex_data.plot(title='Stationary Forex')
# Out:
# Making data stationary...
# <AxesSubplot:title={'center':'Stationary Forex'}>

# %%
print('Running Augmented Dickey-Fuller Test for Stationary Crude Oil...\n')
ADF_Stationarity_Test(stationary_oil_data.values)

print('\n\n\n')

print('Running Augmented Dickey-Fuller Test for Stationary Crude Oil...\n')
ADF_Stationarity_Test(stationary_forex_data.values)
# Out:
# Running Augmented Dickey-Fuller Test for Stationary Crude Oil...
#
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic     -1.139619e+01
# P-Value                 7.848072e-21
# # Lags Used             2.000000e+00
# # Observations Used     2.800000e+02
# Critical Value (1%)    -3.453922e+00
# Critical Value (5%)    -2.871918e+00
# Critical Value (10%)   -2.572300e+00
# dtype: float64
# Is it stationary? True
#
#
#
#
# Running Augmented Dickey-Fuller Test for Stationary Crude Oil...
#
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic     -1.316812e+01
# P-Value                 1.266628e-24
# # Lags Used             1.000000e+00
# # Observations Used     2.810000e+02
# Critical Value (1%)    -3.453838e+00
# Critical Value (5%)    -2.871881e+00
# Critical Value (10%)   -2.572280e+00
# dtype: float64
# Is it stationary? True

# %%
# Testing for cointegration
print('Testing for Cointegration...\n')
sm.tsa.stattools.coint(stationary_oil_data, stationary_forex_data, trend='c', method='aeg', maxlag=None, autolag='aic', return_results=None)
# Out:
# Testing for Cointegration...
# (-12.849898462866625,
#  5.676490453711454e-23,
#  array([-3.93569812, -3.35788282, -3.05952392]))

# %%
oil_cad = pd.DataFrame({'Oil': np.squeeze(stationary_oil_data),
                        'Cad': np.squeeze(stationary_forex_data)})

print('Stationary Oil vs Cad')
oil_cad.head()
# Out:
# Stationary Oil vs Cad
#      Oil       Cad
# 0  0.156 -0.007240
# 1  1.235 -0.005220
# 2  2.182 -0.003110
# 3  0.127  0.002580
# 4 -0.565  0.002785

# %%
# https://medium.com/swlh/using-granger-causality-test-to-know-if-one-time-series-is-impacting-in-predicting-another-6285b9fd2d1c
print('Running Granger Causality Test...\n')
granger_test = grangercausalitytests(oil_cad, maxlag=15)
# Out:
# Running Granger Causality Test...
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0150  , p=0.9027  , df_denom=279, df_num=1
# ssr based chi2 test:   chi2=0.0151  , p=0.9020  , df=1
# likelihood ratio test: chi2=0.0151  , p=0.9020  , df=1
# parameter F test:         F=0.0150  , p=0.9027  , df_denom=279, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0139  , p=0.9862  , df_denom=276, df_num=2
# ssr based chi2 test:   chi2=0.0284  , p=0.9859  , df=2
# likelihood ratio test: chi2=0.0284  , p=0.9859  , df=2
# parameter F test:         F=0.0139  , p=0.9862  , df_denom=276, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1549  , p=0.9265  , df_denom=273, df_num=3
# ssr based chi2 test:   chi2=0.4766  , p=0.9240  , df=3
# likelihood ratio test: chi2=0.4762  , p=0.9241  , df=3
# parameter F test:         F=0.1549  , p=0.9265  , df_denom=273, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1138  , p=0.9776  , df_denom=270, df_num=4
# ssr based chi2 test:   chi2=0.4702  , p=0.9763  , df=4
# likelihood ratio test: chi2=0.4698  , p=0.9764  , df=4
# parameter F test:         F=0.1138  , p=0.9776  , df_denom=270, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2656  , p=0.9316  , df_denom=267, df_num=5
# ssr based chi2 test:   chi2=1.3825  , p=0.9262  , df=5
# likelihood ratio test: chi2=1.3791  , p=0.9266  , df=5
# parameter F test:         F=0.2656  , p=0.9316  , df_denom=267, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2512  , p=0.9585  , df_denom=264, df_num=6
# ssr based chi2 test:   chi2=1.5815  , p=0.9539  , df=6
# likelihood ratio test: chi2=1.5770  , p=0.9542  , df=6
# parameter F test:         F=0.2512  , p=0.9585  , df_denom=264, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.2360  , p=0.9761  , df_denom=261, df_num=7
# ssr based chi2 test:   chi2=1.7470  , p=0.9725  , df=7
# likelihood ratio test: chi2=1.7415  , p=0.9728  , df=7
# parameter F test:         F=0.2360  , p=0.9761  , df_denom=261, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3479  , p=0.9462  , df_denom=258, df_num=8
# ssr based chi2 test:   chi2=2.9667  , p=0.9364  , df=8
# likelihood ratio test: chi2=2.9509  , p=0.9374  , df=8
# parameter F test:         F=0.3479  , p=0.9462  , df_denom=258, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5489  , p=0.8378  , df_denom=255, df_num=9
# ssr based chi2 test:   chi2=5.3078  , p=0.8067  , df=9
# likelihood ratio test: chi2=5.2570  , p=0.8114  , df=9
# parameter F test:         F=0.5489  , p=0.8378  , df_denom=255, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5209  , p=0.8747  , df_denom=252, df_num=10
# ssr based chi2 test:   chi2=5.6436  , p=0.8443  , df=10
# likelihood ratio test: chi2=5.5860  , p=0.8488  , df=10
# parameter F test:         F=0.5209  , p=0.8747  , df_denom=252, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.6764  , p=0.7605  , df_denom=249, df_num=11
# ssr based chi2 test:   chi2=8.1272  , p=0.7019  , df=11
# likelihood ratio test: chi2=8.0082  , p=0.7126  , df=11
# parameter F test:         F=0.6764  , p=0.7605  , df_denom=249, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.6383  , p=0.8085  , df_denom=246, df_num=12
# ssr based chi2 test:   chi2=8.4378  , p=0.7501  , df=12
# likelihood ratio test: chi2=8.3091  , p=0.7605  , df=12
# parameter F test:         F=0.6383  , p=0.8085  , df_denom=246, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.5876  , p=0.8632  , df_denom=243, df_num=13
# ssr based chi2 test:   chi2=8.4875  , p=0.8105  , df=13
# likelihood ratio test: chi2=8.3568  , p=0.8196  , df=13
# parameter F test:         F=0.5876  , p=0.8632  , df_denom=243, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.6348  , p=0.8347  , df_denom=240, df_num=14
# ssr based chi2 test:   chi2=9.9603  , p=0.7651  , df=14
# likelihood ratio test: chi2=9.7803  , p=0.7781  , df=14
# parameter F test:         F=0.6348  , p=0.8347  , df_denom=240, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.6786  , p=0.8045  , df_denom=237, df_num=15
# ssr based chi2 test:   chi2=11.5113 , p=0.7156  , df=15
# likelihood ratio test: chi2=11.2709 , p=0.7332  , df=15
# parameter F test:         F=0.6786  , p=0.8045  , df_denom=237, df_num=15

# %%
# Auto correlation test on raw data
auto_corr_oil = plot_acf(oil_data['close'].values)
auto_corr_oil.show()

auto_corr_cad = plot_acf(forex_data['close'].values)
auto_corr_cad.show()

# %%
# Partial auto correlation test on raw data
cross_corr_oil = plot_pacf(forex_data['close'].values)
cross_corr_oil.show()

cross_corr_cad = plot_pacf(forex_data['close'].values)
cross_corr_cad.show()

# %%
# Cross correlation test on stationary data
xcorr = plt.xcorr(oil_cad['Oil'].values, oil_cad['Cad'].values,  usevlines=True, maxlags=25)
plt.show()

# %%
"""
ARIMAX:
https://pyflux.readthedocs.io/en/latest/arimax.html
http://barnesanalytics.com/analyzing-multivariate-time-series-using-arimax-in-python-with-statsmodels
https://www.kaggle.com/viridisquotient/arimax

Arima:
https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/
"""

"""
Maybe start with 1 ar term.
1,0,0
"""

print('Wow')


model = sm.tsa.arima_model.ARIMA(oil_data['close'].values, order=(1, 1, 5))
res = model.fit()
plt.plot(oil_cad['Oil'])
plt.plot(res.fittedvalues*8, color='red')
# Out:
# Wow

# %%
start_time = datetime(2019, 12, 4) # start datetime for history call
end_time = datetime(2019, 12, 17) # end datetime for history call
pred_oil = qb.AddCfd("WTICOUSD", Resolution.Daily, Market.Oanda).Symbol
pred_oil_data = qb.History(oil, start_time, end_time)
res.plot_predict(1,315)
plt.plot(pred_oil_data['close'].values)
